# %%
from pandas import DataFrame, read_csv, pivot_table
import matplotlib.pyplot as plt

# %%
dados = read_csv('clientes.csv', sep=';')
dados
# Out:
#          Id  Idade Sexo Estado Civil  Sinistros       Prêmio Categoria  \
# 0         1     64    M        viuvo        0.0   774.464232    Sênior
# 1         2     34    F   divorciado        7.0  1411.800897    Adulto
# 2         3     84    F   divorciado        2.0   803.922742    Sênior
# 3         4     42    F       casado        2.0  1142.005576    Adulto
# 4         5     20    M       casado        NaN   940.051137     Jovem
# ...     ...    ...  ...          ...        ...          ...       ...
# 9995   9996     79    F       casado        NaN   975.383433    Sênior
# 9996   9997     65    F   divorciado        0.0  1143.553683    Sênior
# 9997   9998     18    M       casado        1.0  1028.185036     Jovem
# 9998   9999    104    F        viuvo        2.0   813.078427    Sênior
# 9999  10000     90    M       casado        2.0   809.741555    Sênior
#
#          Desconto
# 0      697.017809
# 1     1411.800897
# 2      803.922742
# 3     1142.005576
# ...

# %%
dados.shape
# Out:
# (10000, 8)

# %%
dados.loc[:,'Sinistros'] = dados['Sinistros'].fillna(dados['Sinistros'].mean()).round()
# dados.loc[:,'Sinistros'] = dados['Sinistros'].fillna(0)
dados
# Out:
#          Id  Idade Sexo Estado Civil  Sinistros       Prêmio Categoria  \
# 0         1     64    M        viuvo        0.0   774.464232    Sênior
# 1         2     34    F   divorciado        7.0  1411.800897    Adulto
# 2         3     84    F   divorciado        2.0   803.922742    Sênior
# 3         4     42    F       casado        2.0  1142.005576    Adulto
# 4         5     20    M       casado        3.0   940.051137     Jovem
# ...     ...    ...  ...          ...        ...          ...       ...
# 9995   9996     79    F       casado        3.0   975.383433    Sênior
# 9996   9997     65    F   divorciado        0.0  1143.553683    Sênior
# 9997   9998     18    M       casado        1.0  1028.185036     Jovem
# 9998   9999    104    F        viuvo        2.0   813.078427    Sênior
# 9999  10000     90    M       casado        2.0   809.741555    Sênior
#
#          Desconto
# 0      697.017809
# 1     1411.800897
# 2      803.922742
# 3     1142.005576
# ...

# %%
dados.loc[:,'Desconto'] = round(dados.Desconto, 4)
dados.loc[:,'Sinistros'] = dados['Sinistros'].round()
dados
# Out:
#          Id  Idade Sexo Estado Civil  Sinistros       Prêmio Categoria  \
# 0         1     64    M        viuvo        0.0   774.464232    Sênior
# 1         2     34    F   divorciado        7.0  1411.800897    Adulto
# 2         3     84    F   divorciado        2.0   803.922742    Sênior
# 3         4     42    F       casado        2.0  1142.005576    Adulto
# 4         5     20    M       casado        3.0   940.051137     Jovem
# ...     ...    ...  ...          ...        ...          ...       ...
# 9995   9996     79    F       casado        3.0   975.383433    Sênior
# 9996   9997     65    F   divorciado        0.0  1143.553683    Sênior
# 9997   9998     18    M       casado        1.0  1028.185036     Jovem
# 9998   9999    104    F        viuvo        2.0   813.078427    Sênior
# 9999  10000     90    M       casado        2.0   809.741555    Sênior
#
#        Desconto
# 0      697.0178
# 1     1411.8009
# 2      803.9227
# 3     1142.0056
# 4      940.0511
# ...

# %%
dados = dados.drop('Desconto', axis=1)
dados
# Out:
#          Id  Idade Sexo Estado Civil  Sinistros       Prêmio Categoria
# 0         1     64    M        viuvo        0.0   774.464232    Sênior
# 1         2     34    F   divorciado        7.0  1411.800897    Adulto
# 2         3     84    F   divorciado        2.0   803.922742    Sênior
# 3         4     42    F       casado        2.0  1142.005576    Adulto
# 4         5     20    M       casado        3.0   940.051137     Jovem
# ...     ...    ...  ...          ...        ...          ...       ...
# 9995   9996     79    F       casado        3.0   975.383433    Sênior
# 9996   9997     65    F   divorciado        0.0  1143.553683    Sênior
# 9997   9998     18    M       casado        1.0  1028.185036     Jovem
# 9998   9999    104    F        viuvo        2.0   813.078427    Sênior
# 9999  10000     90    M       casado        2.0   809.741555    Sênior
#
# [10000 rows x 7 columns]

# %%
# Ordenacao por idades
dados_ordenados = dados.sort_values(['Idade'])
dados_ordenados
# Out:
#         Id  Idade Sexo Estado Civil  Sinistros       Prêmio Categoria
# 8549  8550     18    F        viuvo        7.0  1096.768573     Jovem
# 4416  4417     18    F        viuvo        3.0   913.227727     Jovem
# 1274  1275     18    F   divorciado        2.0  1062.875592     Jovem
# 1884  1885     18    F       casado        5.0  1086.886350     Jovem
# 4699  4700     18    M        viuvo        1.0  1126.908786     Jovem
# ...    ...    ...  ...          ...        ...          ...       ...
# 6635  6636    109    M   divorciado        7.0   794.716612    Sênior
# 9287  9288    109    M   divorciado        3.0  1261.341710    Sênior
# 4627  4628    109    M     solteiro        2.0  1310.833982    Sênior
# 5248  5249    109    M        viuvo        5.0  1090.663695    Sênior
# 8409  8410    109    M     solteiro        6.0  1291.797227    Sênior
#
# [10000 rows x 7 columns]

# %%
dados.groupby('Estado Civil')['Prêmio'].mean()
# Out:
# Estado Civil
# casado         999.405640
# divorciado    1002.938158
# solteiro       998.369644
# viuvo          996.139184
# Name: Prêmio, dtype: float64

# %%
dados.groupby('Categoria')['Id'].count()
# Out:
# Categoria
# Adulto    1602
# Jovem     1412
# Sênior    6986
# Name: Id, dtype: int64

# %%
plt.scatter(dados['Estado Civil'], dados['Prêmio'])
plt.show()

# %%
plt.scatter(dados['Categoria'], dados['Prêmio'])
plt.show()

# %%
explode = (0, 0, 0.1)
tabela = dados.groupby('Categoria')['Id'].count()
label = tabela.index
valores = tabela.values
plt.pie(valores, explode=explode, labels=label, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.show()

# %%
tabela = dados.groupby('Sinistros')['Id'].count()
sinistros = [7,1,2,0,5,6,4,3]
valores = sorted(tabela.values/sum(tabela.values))
plt.bar(sinistros, valores)
plt.show()

# %%
tabela = dados.groupby('Categoria')['Sinistros'].count()
sinistros = ['Jovem','Adulto','Sênior']
valores = sorted(tabela.values/sum(tabela.values))
plt.bar(sinistros, valores)
plt.show()

# %%
dados.pivot_table(
    values='Sinistros',
    index='Estado Civil',
    columns='Categoria',
    fill_value='xxx',
    margins=True,
    margins_name='Totais',
    dropna=False,
    aggfunc='sum'
)
# Out:
# Categoria     Adulto  Jovem  Sênior   Totais
# Estado Civil
# casado          1397   1230    5874   8501.0
# divorciado      1453   1236    6203   8892.0
# solteiro        1356   1184    5957   8497.0
# viuvo           1312   1234    6008   8554.0
# Totais          5518   4884   24042  34444.0
